# %%
#wap in python to check whether a person can donate blood or not,,, >=18 age, <=50 weight:
a=int(input("age of donor:"))
b=float(input("weight of the donor:"))
if a>=18 and b>=50:
                print("donor is eligible")
else:
                print("donor is not eligible")
# Out:
# age of donor: 19
# weight of the donor: 49.5
# donor is not eligible

# %%
#wap to prep a simple calculate for 2 values:

# %%
#wap to prep a simple calculate for 2 values:
# Out:
# age of the buyer 21
# price of ticket=180

# %%
age= int(input("enter the age: "))
salary= int(input("enter monthly salary: "))
experience= int(input("enter work experience"))

if age>=21:
    if salary>=25000:
        if experience>=2:
            print("eligible for loan")
        else:
            print("not sufficient:insuff work exp")
    else:
        print("not eligible:low salary")
else:
    print("not eligible:age not valid")
# Out:
# enter the age:  23
# enter monthly salary:  25000
# enter work experience 3
# eligible for loan

# %%
#WAP TO CHECK IF ENTERED CHARACTER IS A VOWEL:
vowel=input("enter the alphabet")
if vowel==("a","e","i","o","u"):
    print("it is vowel")
else: 
    print("it is not vowel")
# Out:
# enter the alphabet d
# it is not vowel

# %%
#WAP TO CHECK IS THYE TEMP IS ABOVE 30 DEGREE CELCIUS:
temp=int(input("enter the temperature"))
if temp>30:
         print("Temperature is above 30 degree celcius")
else:
         print("Temperature is not above 30 degree celcius")
# Out:
# enter the temperature 31
# temp is above 30 degree celcius

# %%
#WAP TO CHECK IF A PASSWORD LENGTH IS ATLEAST 8 CHARACTERS:
password= str(input("enter the password: "))
if len(password)>=8:
    print("it is 8 characters")
else:
    print("it is not 8 characters")
# Out:
# enter the password:  bhavika12
# it is 8 characters

# %%
#wap to check if the first numbe ren entered is greater than the second number:
a=int(input("

# %%
#WAP TO CHECK FOR ATM WITHDRAWL:
pin=("1234")
balance= 5000
enter.pin= int(input("enter your pin"))
if enter.pin==pin:
    amount=int(input("enter the amount to withdraw"))
    if amount<= balance:
      print("withdrawl succesful")
    print("remaining balance:", balance)
    else:
        print("error: insufficient balance")
else:
    print("error:incorrrect pin")
# Out:
#   Cell In[18], line 10
#     else:
#     ^
# SyntaxError: invalid syntax
