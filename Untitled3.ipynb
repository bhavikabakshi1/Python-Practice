# %%
str1= "hey i am here"
str2= "hello everyone how are you"
print(str1[0])
print(str2[-1])
# Out:
# h
# u

# %%
str1="HELLO"
str2="WORLD"
print(str1*3)
print(str1+str2)
print(str1[4])
print(str1[2:4])
print('w' in str1)
print('wo' not in str2)
# Out:
# HELLOHELLOHELLO
# HELLOWORLD
# O
# LL
# False
# True

# %%
str1 = " how many students are there "
str2= str1[1:10] + str1[-10:-1]
print(str2)
print(str1[10:18])

# %%
s = "hellow and welcome"
s = s.lower()
vowels = "aeiou"
count = 0
for v in vowels:
    count += s.count(v)
print("Number of vowels =", count)

# %%
s= "hellow and welcome"
vowels = "aeiouAEIOU"
vowel_list = [ch for ch in s if ch in vowels]
print("Number of vowels =", len(vowel_list))

# %%
mystring=("apple","banana", "mango")
x ="#".join(mytsring)
print(x)
my_string = " i lik
# Out:
#   Cell In[23], line 4
#     my_string =
#                 ^
# SyntaxError: invalid syntax

# %%
name = "bhavika"
for char in name:
    print(char)
# Out:
# b
# h
# a
# v
# i
# k
# a

# %%
str="hello!"
i=0
while i<len(str):
    print(str[i])
    i+=1
# Out:
# h
# e
# l
# l
# o

# %%
fruits = ["apple","banana","cherry","kiwi","mango"]
newlist = [x for x in fruits if x!= "apple"]
print(newlist)
# Out:
# ['banana', 'cherry', 'kiwi', 'mango']

# %%
#check if string s is pallindrome or not:
s="madam"
if s==s[::-1]:
  print("is pallindrome")
else:
  print("not pallindrome")

# %%
password = input("Enter your password: ")
has_upper = False
has_lower = False
for char in password:
    if char.isupper():
        has_upper = True
    if char.islower():
        has_lower = True
if has_upper and has_lower:
    print("Password is STRONG.")
else:
    print("Password is WEAK.")
# Out:
# Enter your password:  23
# Password is WEAK.

# %%
# college automation system needs to extract the domain name from a each student's email id.
email = input("Enter your email id: ")
domain = email.split("@")[1]
print("Domain name:", domain)
# Out:
# Enter your email id:  abcd@gmail.com
# Domain name: gmail.com

# %%
emails=["arp.beai25@chitkara.edu.in","abc@yahoo.com","abc@gmail.com"]
for email in emails:
    domain=email.split('@')[1]
    print(f"Domain:{domain}")
# Out:
# Domain:chitkara.edu.in
# Domain:yahoo.com
# Domain:gmail.com

# %%
 input="Hello students how are you where you can go right now"
word_count=len(input.split())
print("word count:",word_count)
# Out:
# word count: 11

# %%
s = input("Enter a string: ")
words = s.split()
freq = {}
for word in words:
    freq[word] = freq.get(word, 0) + 1
print(freq)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 s = input("Enter a string: ")
#       2 words = s.split()
#       3 freq = {}
#
# TypeError: 'str' object is not callable

# %%
# a module in a python is simply a file that contains python code functions,classes and variables . the  modules can reuse in other programs. the modules has 2 proeprties
that is it helps #in organisig a code into 1.  smaller parts with the help of built in modules such as math random and operating system or u can create your own custom modules

# %%
import math
print(math.sqrt(5))
# Out:
#   Cell In[2], line 3
#
#     ^
# _IncompleteInputError: incomplete input

# %%
n = int(input())#13
matrix = []
for _ in range(n):
    row = list(map(int, input().split()))
    matrix.append(row)
diagonal = []
for i in range(n):
    if i < len(matrix[i]):
        diagonal.append(matrix[i][i])
print("Diagonal Elements:", diagonal)
print("Sum:", sum(diagonal))
print("Reversed:", diagonal[::-1])
# Out:
#  4
#  10 20 30 40
#  5 6 7
#  3 0 9
#  8 1 4 2 0
# Diagonal Elements: [10, 6, 9, 2]
# Sum: 27
# Reversed: [2, 9, 6, 10]

# %%
#14# Program to divide two integers using try and except
try:
    num1 = int(input("Enter the first integer: "))
    num2 = int(input("Enter the second integer: "))
    result = num1 / num2
    print("The result of division is:", result)
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
except ValueError:
    print("Error: Please enter only integer values.")
# Out:
# Enter the first integer:  15
# Enter the second integer:  3
# The result of division is: 5.0

# %%
#15
class Student:
    def __init__(self, name, roll_number, marks):
        self.name = name
        self.roll_number = roll_number
        self.marks = marks
    def display_details(self):
        print("Student Name:", self.name)
        print("Roll Number:", self.roll_number)
        print("Marks:", self.marks)
    def check_result(self):
        if self.marks >= 40:
            print("Result: Passed")
        else:
            print("Result: Failed")
name = input("Enter student name: ")
roll_number = int(input("Enter roll number: "))
marks = int(input("Enter marks out of 100: "))
if marks < 0 or marks > 100:
    print("Marks should be between 0 and 100")
else:
    student1 = Student(name, roll_number, marks)
    student1.display_details()
    student1.check_result()
# Out:
# Enter student name:  bhavika
# Enter roll number:  3769
# Enter marks out of 100:  78
# Student Name: bhavika
# Roll Number: 3769
# Marks: 78
# Result: Passed

# %%
#16
class Student:
    def __init__(self, name, roll_number, marks):
        self.name = name
        self.roll_number = roll_number
        self.marks = marks
    def display_details(self):
        print("Student Name:", self.name)
        print("Roll Number:", self.roll_number)
        print("Marks:", self.marks)
    def check_result(self):
        if self.marks >= 40:
            print("Result: Passed")
        else:
            print("Result: Failed")
name = input("Enter student name: ")
roll_number = int(input("Enter roll number: "))
marks = int(input("Enter marks out of 100: "))
if marks < 0 or marks > 100:
    print("Marks should be between 0 and 100")
else:
    student1 = Student(name, roll_number, marks)
    student1.display_details()
    student1.check_result()

# %%
#16
def add(a, b):
    return a + b
def sub(a, b):
    return a - b
def mul(a, b):
    return a * b
def div(a, b):
    return a / b
print("Simple Calculator")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")
try:
    choice = int(input("Enter your choice (1-4): "))
    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))
    if choice == 1:
        print("Result =", add(num1, num2))
    elif choice == 2:
        print("Result =", sub(num1, num2))
    elif choice == 3:
        print("Result =", mul(num1, num2))
    elif choice == 4:
        try:
            print("Result =", div(num1, num2))
        except ZeroDivisionError:
            print("Error: Division by zero is not allowed")
    else:
        print("Invalid Choice")
except ValueError:
    print("Invalid Input! Please enter numbers only.")
except Exception as e:
    print("Some error occurred:", e)
